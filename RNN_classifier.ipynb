# %% [markdown]
# ## RNN Classifier Setup

# %%
import re

def replace(string, substitutions):
    substrings = sorted(substitutions, key=len, reverse=True)
    regex = re.compile('|'.join(map(re.escape, substrings)))
    return regex.sub(lambda match: substitutions[match.group(0)], string)

# %%
from nltk.corpus import reuters
from sklearn.preprocessing import MultiLabelBinarizer
import keras
from nltk.corpus import reuters
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, SpatialDropout1D, SimpleRNN
from keras.layers import Embedding
from keras.callbacks import ModelCheckpoint
import os
import numpy as np
from sklearn.metrics import roc_auc_score
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
 
# List of document ids
all_docs_id = reuters.fileids()
 
train_docs_id = list(filter(lambda doc: doc.startswith("train"),
                            all_docs_id))
test_docs_id = list(filter(lambda doc: doc.startswith("test"),
                           all_docs_id))
 
train_docs = [reuters.raw(doc_id) for doc_id in train_docs_id]
test_docs = [reuters.raw(doc_id) for doc_id in test_docs_id]
all_docs = [reuters.raw(doc_id) for doc_id in all_docs_id]

# Transform multilabel labels
mlb = MultiLabelBinarizer()
train_labels = mlb.fit_transform([reuters.categories(doc_id)
                                  for doc_id in train_docs_id])
test_labels = mlb.transform([reuters.categories(doc_id)
                             for doc_id in test_docs_id])
# Out:
# C:\Users\Tan\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# removes \n from all the text
subst = {"\n" :""}

for i, doc in enumerate(test_docs):
    test_docs[i] = replace(doc, subst)
    
for i, doc in enumerate(train_docs):
    train_docs[i] = replace(doc, subst)
    
for i, doc in enumerate(all_docs):
    all_docs[i] = replace(doc, subst)

# %%
t = keras.preprocessing.text.Tokenizer(num_words=5000, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True, split=' ', char_level=False, oov_token=None)
t.fit_on_texts(all_docs)

# %%
print(t.word_index)
# Out:
# {'the': 1, 'of': 2, 'to': 3, 'in': 4, 'and': 5, 'said': 6, 'a': 7, 'mln': 8, 'vs': 9, 'for': 10, 'dlrs': 11, 'it': 12, '000': 13, '1': 14, 'pct': 15, 'on': 16, 'lt': 17, 'cts': 18, 'from': 19, 'is': 20, 'that': 21, 'its': 22, 'year': 23, 'by': 24, 'at': 25, 'net': 26, '2': 27, 'u': 28, 'be': 29, 'with': 30, 's': 31, 'will': 32, 'billion': 33, 'was': 34, 'he': 35, 'loss': 36, '3': 37, 'has': 38, '5': 39, 'would': 40, 'as': 41, 'an': 42, 'not': 43, '4': 44, '1986': 45, 'shr': 46, 'company': 47, 'inc': 48, 'which': 49, 'but': 50, 'this': 51, 'bank': 52, '7': 53, '6': 54, 'oil': 55, 'corp': 56, 'last': 57, 'or': 58, '8': 59, 'are': 60, 'share': 61, 'have': 62, 'trade': 63, 'were': 64, 'had': 65, 'one': 66, 'profit': 67, '0': 68, '9': 69, 'about': 70, 'market': 71, 'new': 72, 'qtr': 73, 'two': 74, 'shares': 75, 'stock': 76, 'also': 77, 'they': 78, 'tonnes': 79, '1987': 80, '10': 81, 'revs': 82, 'up': 83, 'sales': 84, 'prices': 85, 'may': 86, 'per': 87, 'been': 88, 'march': 89, 'april': 90, 'after': 91, 'group': 92, 'first': 93, 'more': 94, 'rate': 95, 'co': 96, 'quarter': 97, 'price': 98, 'than': 99, 'february': 100, '15': 101, 'offer': 102, 'january': 103, '1985': 104, 'other': 105, 'three': 106, '31': 107, 'exchange': 108, 'note': 109, '20': 110, '30': 111, 'japan': 112, 'if': 113, 'agreement': 114, 'week': 115, '50': 116, 'government': 117, 'dollar': 118, 'no': 119, 'tax': 120, 'against': 121, 'could': 122, 'production': 123, 'over': 124, '12': 125, 'we': 126, 'foreign': 127, 'told': 128, 'some': 129, 'international': 130, 'ltd': 131, 'interest': 132, 'expected': 133, 'their': 134, 'rose': 135, '25': 136, 'dlr': 137, 'rates': 138, 'rise': 139, 'total': 140, 'under': 141, 'five': 142, 'current': 143, 'record': 144, 'all': 145, 'nine': 146, 'today': 147, 'end': 148, 'month': 149, 'stg': 150, 'exports': 151, '11': 152, '16': 153, 'six': 154, 'there': 155, 'oper': 156, 'official': 157, 'increase': 158, '13': 159, 'growth': 160, 'board': 161, 'added': 162, 'meeting': 163, 'earlier': 164, 'avg': 165, 'earnings': 166, 'shrs': 167, 'between': 168, 'because': 169, '87': 170, 'export': 171, 'common': 172, 'sale': 173, 'world': 174, 'dividend': 175, 'wheat': 176, 'economic': 177, '17': 178, 'months': 179, 'into': 180, 'money': 181, '14': 182, 'unit': 183, 'industry': 184, 'major': 185, 'american': 186, 'cash': 187, 'made': 188, '18': 189, 'four': 190, 'spokesman': 191, 'officials': 192, 'west': 193, 'japanese': 194, 'banks': 195, 'buy': 196, 'report': 197, 'now': 198, 'investment': 199, 'ec': 200, 'imports': 201, 'mths': 202, 'december': 203, 'while': 204, 'acquisition': 205, 'business': 206, 'pay': 207, 'any': 208, 'department': 209, 'analysts': 210, 'countries': 211, 'operations': 212, 'financial': 213, 'when': 214, '28': 215, 'stake': 216, 'national': 217, 'agreed': 218, 'cut': 219, 'says': 220, 'fell': 221, 'united': 222, 'further': 223, 'central': 224, 'down': 225, 'sources': 226, 'deficit': 227, 'due': 228, 'around': 229, 'president': 230, 'includes': 231, 'lower': 232, 'compared': 233, 'should': 234, 'companies': 235, 'products': 236, '4th': 237, 'years': 238, 'yen': 239, 'only': 240, 'states': 241, 'securities': 242, 'federal': 243, 'time': 244, 'higher': 245, 'debt': 246, 'since': 247, 'gas': 248, '19': 249, 'prior': 250, 'currency': 251, 'markets': 252, 'out': 253, 'reserves': 254, 'period': 255, 'shareholders': 256, 'capital': 257, 'statement': 258, 'merger': 259, 'sugar': 260, 'next': 261, 'gain': 262, '22': 263, 'sell': 264, 'reported': 265, 'trading': 266, 'credit': 267, 'before': 268, '100': 269, 'policy': 270, 'assets': 271, 'fall': 272, 'k': 273, 'tender': 274, 'chairman': 275, 'crude': 276, 'june': 277, 'ended': 278, 'take': 279, 'minister': 280, 'general': 281, 'based': 282, 'through': 283, 'talks': 284, 'surplus': 285, '40': 286, 'state': 287, '24': 288, 'high': 289, 'commission': 290, 'domestic': 291, 'output': 292, 'figures': 293, 'term': 294, 'grain': 295, 'plan': 296, 'set': 297, 'demand': 298, 'announced': 299, 'ca ...

# %%
encoded_test_docs = t.texts_to_sequences(test_docs)
encoded_train_docs = t.texts_to_sequences(train_docs)

# %% [markdown]
# ## RNN Classifier

# %% [markdown]
# ### Set hyperparameters

# %%
output_dir = r'model_output\rnn_classifier'

epochs = 32
batch_size = 128

n_dim = 64
n_unique_words = 10000
max_review_length = 100
pad_type = trunc_type = 'pre'
drop_embed = 0.2

n_rnn = 256
dropout_rnn = 0.2

# could add dense layer after rnn, but it's not common practice. Do try out when you have time

# %% [markdown]
# ### Preprocess data

# %%
encoded_train_docs = pad_sequences(encoded_train_docs, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value = 0)
encoded_test_docs = pad_sequences(encoded_test_docs, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value = 0)

# %% [markdown]
# ### NN Architecture

# %%
model = Sequential()
model.add(Embedding(n_unique_words, n_dim, input_length=max_review_length))
model.add(SpatialDropout1D(drop_embed))
model.add(SimpleRNN(n_rnn, dropout=dropout_rnn))
model.add(Dense(90, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 64)           640000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 100, 64)           0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 256)               82176
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                23130
# =================================================================
# Total params: 745,306
# Trainable params: 745,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def sum_binary_crossentropy(y_true, y_pred):
    return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)

# %% [markdown]
# check out https://github.com/keras-team/keras/issues/2275 for categorical_accuracy intuition

# %%
model.compile(loss=sum_binary_crossentropy, optimizer='adam', metrics=['categorical_accuracy'])

# %%
modelcheckpoint = ModelCheckpoint(filepath=output_dir+"\weights.{epoch:02d}.hdf5")

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ### Train

# %%
model.fit(encoded_train_docs, train_labels, batch_size = batch_size, epochs=epochs, verbose=1, 
          validation_data=(encoded_test_docs, test_labels), callbacks=[modelcheckpoint])
# Out:
# Train on 7769 samples, validate on 3019 samples
# Epoch 1/32
# 7769/7769 [==============================] - 7s 903us/step - loss: 44.4467 - categorical_accuracy: 0.1048 - val_loss: 8.0114 - val_categorical_accuracy: 0.3587
# Epoch 2/32
# 7769/7769 [==============================] - 6s 717us/step - loss: 5.4230 - categorical_accuracy: 0.3659 - val_loss: 4.7768 - val_categorical_accuracy: 0.3587
# Epoch 3/32
# 7769/7769 [==============================] - 5s 678us/step - loss: 4.6335 - categorical_accuracy: 0.3659 - val_loss: 4.5911 - val_categorical_accuracy: 0.3587
# Epoch 4/32
# 7769/7769 [==============================] - 5s 662us/step - loss: 4.4928 - categorical_accuracy: 0.3663 - val_loss: 4.4991 - val_categorical_accuracy: 0.3587
# Epoch 5/32
# 7769/7769 [==============================] - 5s 659us/step - loss: 4.3989 - categorical_accuracy: 0.3810 - val_loss: 4.4010 - val_categorical_accuracy: 0.3952
# Epoch 6/32
# 7769/7769 [==============================] - 5s 654us/step - loss: 4.3075 - categorical_accuracy: 0.3927 - val_loss: 4.3530 - val_categorical_accuracy: 0.4031
# Epoch 7/32
# 7769/7769 [==============================] - 5s 651us/step - loss: 4.2819 - categorical_accuracy: 0.3934 - val_loss: 4.4115 - val_categorical_accuracy: 0.3991
# Epoch 8/32
# 7769/7769 [==============================] - 5s 681us/step - loss: 4.2557 - categorical_accuracy: 0.3850 - val_loss: 4.3030 - val_categorical_accuracy: 0.3885
# Epoch 9/32
# 7769/7769 [==============================] - 5s 660us/step - loss: 4.1470 - categorical_accuracy: 0.3994 - val_loss: 4.3070 - val_categorical_accuracy: 0.3816
# Epoch 10/32
# 7769/7769 [==============================] - 5s 665us/step - loss: 4.1238 - categorical_accuracy: 0.3961 - val_loss: 4.3424 - val_categorical_accuracy: 0.3799
# Epoch 11/32
# 7769/7769 [==============================] - 5s 668us/step - loss: 4.0709 - categorical_accuracy: 0.4055 - val_loss: 4.2745 - val_categorical_accuracy: 0.3885
# Epoch 12/32
# 7769/7769 [==============================] - 5s 668us/step - loss: 4.1199 - categorical_accuracy: 0.3964 - val_loss: 4.5334 - val_categorical_accuracy: 0.3667
# Epoch 13/32
# 7769/7769 [==============================] - 5s 669us/step - loss: 4.0228 - categorical_accuracy: 0.4065 - val_loss: 4.4190 - val_categorical_accuracy: 0.3342
# Epoch 14/32
# 7769/7769 [==============================] - 5s 675us/step - loss: 4.0101 - categorical_accuracy: 0.4181 - val_loss: 4.2629 - val_categorical_accuracy: 0.3945
# Epoch 15/32
# 7769/7769 [==============================] - 5s 659us/step - loss: 3.9795 - categorical_accuracy: 0.4181 - val_loss: 4.3131 - val_categorical_accuracy: 0.4223
# Epoch 16/32
# 7769/7769 [==============================] - 5s 670us/step - loss: 3.9744 - categorical_accuracy: 0.4191 - val_loss: 4.3053 - val_categorical_accuracy: 0.3882
# Epoch 17/32
# 7769/7769 [==============================] - 5s 671us/step - loss: 3.9133 - categorical_accuracy: 0.4325 - val_loss: 4.2188 - val_categorical_accuracy: 0.4008
# Epoch 18/32
# 7769/7769 [==============================] - 5s 669us/step - loss: 3.7607 - categorical_accuracy: 0.4666 - val_loss: 4.5149 - val_categorical_accuracy: 0.3789
# Epoch 19/32
# 7769/7769 [==============================] - 5s 665us/step - loss: 3.8960 - categorical_accuracy: 0.4491 - val_loss: 4.1721 - val_categorical_accuracy: 0.4154
# Epoch 20/32
# 7769/7769 [==============================] - 5s 669us/step - loss: 3.8395 - categorical_accuracy: 0.4493 - val_loss: 4.3494 - val_categorical_accuracy: 0.4730
# Epoch 21/32
# 7769/7769 [==============================] - 5s 663us/step - loss: 58.2470 - categorical_accuracy: 0.3161 - val_loss: 12.8196 - val_categorical_accuracy: 0.3548
# Epoch 22/32
# 7769/7769 [==============================] - 5s 675us/step - loss: 8.6336 - categorical_accuracy: 0.3601 - val_loss: 7.0457 - val_categorical_accuracy: 0.3584
# Epoch 23/32
# 7769/7769 [==============================] - 5s 672us/step - loss: 5.4325 - categorical_accuracy: 0.3654 - val_loss: 6.2783 - val_categorical_accuracy: 0.3584
# Epoch 24/32
# 7769/7769 [==============================] - 5s 677us/step - loss: 5.0319 - categorical_accuracy: 0.3652 - val_loss: 6.1037 - val_categorical_accuracy: 0.3584
# Epoch 25/32
# 7769/7769 [==============================] - 5s 669us/step - loss: 4.9306 - categorical_accuracy: 0.3654 - val_loss: 6.0027 - val_categorical_accuracy: 0.3584
# Epoch 26/32
# 7769/7769 [==============================] - 5s 685us/step - loss: 4.9680 - categorical_accuracy: 0.3654 - val_loss: 5.9353 - val_categorical_accuracy: 0.3584
# Epoch 27/32
# 7769/7769 [==============================] - 5s 676us/step - loss: 5.0077 - categorical_accuracy: 0.3653 - val_loss: 5.8804 - val_categorical_accuracy: 0.3584
# Epoch 28/32
# 7769/7769 [==============================] - 5s 664us/step - loss: 4.8609 - categorical_accuracy: 0.3666 - val_loss: 5.6911 - val_categorical_accuracy: 0.3584
# Epoch 29/32
# 7769/7769 [==============================] - 5s 680us/step - loss: 4.6710 - categorical_accuracy: 0.3694 - val_loss: 5.6498 - val_categorical_accuracy: 0.3610
# Epoch 30/32
# 7769/7769 [==============================] - 5s 679us/step - loss: 4.7289 - categorical_accuracy: 0.3704 - val_loss: 5.6234 - val_categorical_accuracy: 0.3610
# Epoch 31/32
# 7769/7769 [==============================] - 5s 672us/step - loss: 4.7335 - categorical_accuracy: 0.3768 - val_loss: 5.5754 - val_categorical_accuracy: 0.3928
# Epoch 32/32
# 7769/7769 [==============================] - 5s 673us/step - loss: 4.8372 - categorical_accuracy: 0.3923 - val_loss: 5.5532 - val_categorical_accuracy: 0.3640

# %% [markdown]
# ### Load the ideal weights based on above result

# %%
model.load_weights(output_dir+'/weights.20.hdf5')

# %%
y_hat = model.predict(encoded_test_docs)

# %% [markdown]
# ### ROC AUC Score
# macro checks per category while micro checks per sample

# %%
pct_auc_macro = roc_auc_score(test_labels, y_hat, average = 'macro')*100
pct_auc_micro = roc_auc_score(test_labels, y_hat, average = 'micro')*100
pct_auc_macro, pct_auc_micro
# Out:
# (64.81237484658035, 90.88022591294111)

# %% [markdown]
# ### Random Check

# %%
print(y_hat[7][26])
print(test_labels[7][26])
# Out:
# 0.021985628
# 1

# %% [markdown]
# ### Label ranking average precision
# Label ranking average precision (LRAP) is the average over each ground truth label assigned to each sample, of the ratio of true vs. total labels with lower score. This metric is used in multilabel ranking problem, where the goal is to give better rank to the labels associated to each sample.
#
# The obtained score is always strictly greater than 0 and the best value is 1.

# %%
from sklearn.metrics import label_ranking_average_precision_score
label_ranking_average_precision_score(test_labels, y_hat)
# Out:
# 0.5926923860770521

# %% [markdown]
# ### Label Ranking Loss
# The label_ranking_loss function computes the ranking loss which averages over the samples the number of label pairs that are incorrectly ordered, i.e. true labels have a lower score than false labels, weighted by the inverse number of false and true labels. The lowest achievable ranking loss is zero.

# %%
from sklearn.metrics import label_ranking_loss
label_ranking_loss(test_labels, y_hat)
# Out:
# 0.07620343478619537
